# %%
# !pip install crewai crewai-tools
# !pip install crewai
# Out:
# Requirement already satisfied: crewai in c:\projects\clinical\env\lib\site-packages (0.65.2)
# Requirement already satisfied: crewai-tools in c:\projects\clinical\env\lib\site-packages (0.12.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python<5.0.0,>=4.7.1 in c:\projects\clinical\env\lib\site-packages (from crewai) (4.7.2)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in c:\projects\clinical\env\lib\site-packages (from crewai) (8.1.7)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.114 in c:\projects\clinical\env\lib\site-packages (from crewai) (0.1.122)
# Requirement already satisfied: instructor==1.3.3 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.3.3)
# Requirement already satisfied: json-repair<0.26.0,>=0.25.2 in c:\projects\clinical\env\lib\site-packages (from crewai) (0.25.3)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: langchain<0.3.0,>=0.2.16 in c:\projects\clinical\env\lib\site-packages (from crewai) (0.2.16)
# Requirement already satisfied: litellm<2.0.0,>=1.44.22 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.48.7)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.50.2)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.27.0)
# Requirement already satisfied: poetry<2.0.0,>=1.8.3 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.8.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in c:\projects\clinical\env\lib\site-packages (from crewai) (2.9.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.0.1)
# Requirement already satisfied: regex<2025.0.0,>=2024.9.11 in c:\projects\clinical\env\lib\site-packages (from crewai) (2024.9.11)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (3.10.8)
# Requirement already satisfied: docstring-parser<0.17,>=0.16 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.5.0,>=0.4.1 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (0.4.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (2.23.4)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (13.8.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (8.5.0)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (0.12.5)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\projects\clinical\env\lib\site-packages (from crewai-tools) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.22 in c:\projects\clinical\env\lib\site-packages (from crewai-tools) (0.4.24)
# Requirement already satisfied: docker<8.0.0,>=7.1.0 in c:\projects\clinical\env\lib\site-packages (from crewai-tools) (7.1.0)
# Requirement already satisfied: docx2txt<0.9,>=0.8 in c:\projects\clinical\env\lib\site-packages (from crewai-tools) (0.8)
# Requirement already satisfied: lancedb<0.6.0,>=0.5.4 in c:\projects\clinical\env\lib\site-packages (from crewai-tools) (0.5.7)
# Requirement already satisfied: pyright<2.0.0,>=1.1.350 in c:\projects\clinical\env\lib\site-packages (from crewai-tools) (1.1.382.post1)
# Requirement already satisfied: pytest<9.0.0,>=8.0.0 in c:\projects\clinical\env\lib\site-packages (from crewai-tools) (8.3.3)
# Requirement already satisfied: pytube<16.0.0,>=15.0.0 in c:\projects\clinical\env\lib\site-packages (from crewai-tools) (15.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\projects\clinical\env\lib\site-packages (from crewai-tools) (2.32.3)
# Requirement already satisfied: selenium<5.0.0,>=4.18.1 in c:\projects\clinical\env\lib\site-packages (from crewai-tools) (4.25.0)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in c:\projects\clinical\env\lib\site-packages (from auth0-python<5.0.0,>=4.7.1->crewai) (43.0.1)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in c:\projects\clinical\env\lib\site-packages (from auth0-python<5.0.0,>=4.7.1->crewai) (2.9.0)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in c:\projects\clinical\env\lib\site-packages (from auth0-python<5.0.0,>=4.7.1->crewai) (2.2.3)
# Requirement already satisfied: soupsieve>1.2 in c:\projects\clinical\env\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->crewai-tools) (2.6)
# Requirement already satisfied: build>=1.0.3 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (1.2.2)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (0.115.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\projects\clinical\env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools) (0.31.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (3.6.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (4.12.2)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (1.19.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (0.48b0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (0.20.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (1.66.2)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (4.2.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (31.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\projects\clinical\env\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools) (3.10.7)
# Requirement already satisfied: colorama in c:\projects\clinical\env\lib\site-packages (from click<9.0.0,>=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: pywin32>=304 in c:\projects\clinical\env\lib\site-packages (from docker<8.0.0,>=7.1.0->crewai-tools) (306)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (1.13.3)
# Requirement already satisfied: cohere<6.0,>=5.3 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (5.11.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (1.68.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.44)
# Requirement already satisfied: langchain-cohere<0.2.0,>=0.1.4 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.9)
# Requirement already satisfied: langchain-community<0.3.0,>=0.2.6 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.2.17)
# Requirement already satisfied: langchain-openai<0.2.0,>=0.1.7 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.25)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.15 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.17)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (4.3.1)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.7.7)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (2.0.35)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.7.0)
# Requirement already satisfied: deprecation in c:\projects\clinical\env\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools) (2.1.0)
# Requirement already satisfied: pylance==0.9.18 in c:\projects\clinical\env\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools) (0.9.18)
# Requirement already satisfied: ratelimiter~=1.0 in c:\projects\clinical\env\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools) (1.2.0.post0)
# Requirement already satisfied: retry>=0.9.2 in c:\projects\clinical\env\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools) (0.9.2)
# Requirement already satisfied: attrs>=21.3.0 in c:\projects\clinical\env\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools) (23.2.0)
# Requirement already satisfied: semver>=3.0 in c:\projects\clinical\env\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools) (3.0.2)
# Requirement already satisfied: cachetools in c:\projects\clinical\env\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools) (5.5.0)
# Requirement already satisfied: pyarrow>=12 in c:\projects\clinical\env\lib\site-packages (from pylance==0.9.18->lancedb<0.6.0,>=0.5.4->crewai-tools) (17.0.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\projects\clinical\env\lib\site-packages (from langchain<0.3.0,>=0.2.16->crewai) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in c:\projects\clinical\env\lib\site-packages (from langchain<0.3.0,>=0.2.16->crewai) (0.2.41)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\projects\clinical\env\lib\site-packages (from langchain<0.3.0,>=0.2.16->crewai) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\projects\clinical\env\lib\site-packages (from langchain<0.3.0,>=0.2.16->crewai) (0.1.129)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\projects\clinical\env\lib\site-packages (from litellm<2.0.0,>=1.44.22->crewai) (6.11.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\projects\clinical\env\lib\site-packages (from litellm<2.0.0,>=1.44.22->crewai) (3.1.4)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\projects\clinical\env\lib\site-packages (from litellm<2.0.0,>=1.44.22->crewai) (4.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\projects\clinical\env\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\projects\clinical\env\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\projects\clinical\env\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (0.27.2)
# Requirement already satisfied: sniffio in c:\projects\clinical\env\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.27.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-proto==1.27.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (4.25.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai) (0.48b0)
# Requirement already satisfied: cachecontrol<0.15.0,>=0.14.0 in c:\projects\clinical\env\lib\site-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry<2.0.0,>=1.8.3->crewai) (0.14.0)
# Requirement already satisfied: cleo<3.0.0,>=2.1.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (2.1.0)
# Requirement already satisfied: crashtest<0.5.0,>=0.4.1 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (0.4.1)
# Requirement already satisfied: dulwich<0.22.0,>=0.21.2 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (0.21.7)
# Requirement already satisfied: fastjsonschema<3.0.0,>=2.18.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (2.20.0)
# Requirement already satisfied: installer<0.8.0,>=0.7.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (0.7.0)
# Requirement already satisfied: keyring<25.0.0,>=24.0.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (24.3.1)
# Requirement already satisfied: packaging>=23.1 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (24.1)
# Requirement already satisfied: pexpect<5.0.0,>=4.7.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (4.9.0)
# Requirement already satisfied: pkginfo<2.0,>=1.10 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.11.1)
# Requirement already satisfied: platformdirs<5,>=3.0.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (4.3.6)
# Requirement already satisfied: poetry-core==1.9.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.9.0)
# Requirement already satisfied: poetry-plugin-export<2.0.0,>=1.6.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.8.0)
# Requirement already satisfied: pyproject-hooks<2.0.0,>=1.0.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.2.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.0.0)
# Requirement already satisfied: shellingham<2.0,>=1.5 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.5.4)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (2.0.1)
# Requirement already satisfied: tomlkit<1.0.0,>=0.11.4 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (0.13.2)
# Requirement already satisfied: trove-classifiers>=2022.5.19 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (2024.9.12)
# Requirement already satisfied: virtualenv<21.0.0,>=20.23.0 in c:\projects\clinical\env\lib\site-packages (from poetry<2.0.0,>=1.8.3->crewai) (20.26.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\projects\clinical\env\lib\site-packages (from pydantic<3.0.0,>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: nodeenv>=1.6.0 in c:\projects\clinical\env\lib\site-packages (from pyright<2.0.0,>=1.1.350->crewai-tools) (1.9.1)
# Requirement already satisfied: iniconfig in c:\projects\clinical\env\lib\site-packages (from pytest<9.0.0,>=8.0.0->crewai-tools) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\projects\clinical\env\lib\site-packages (from pytest<9.0.0,>=8.0.0->crewai-tools) (1.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\projects\clinical\env\lib\site-packages (from pytest<9.0.0,>=8.0.0->crewai-tools) (1.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\projects\clinical\env\lib\site-packages (from requests<3.0.0,>=2.31.0->crewai-tools) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\projects\clinical\env\lib\site-packages (from requests<3.0.0,>=2.31.0->crewai-tools) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\projects\clinical\env\lib\site-packages (from requests<3.0.0,>=2.31.0->crewai-tools) (2024.8.30)
# Requirement already satisfied: trio~=0.17 in c:\projects\clinical\env\lib\site-packages (from selenium<5.0.0,>=4.18.1->crewai-tools) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\projects\clinical\env\lib\site-packages (from selenium<5.0.0,>=4.18.1->crewai-tools) (0.11.1)
# Requirement already satisfied: websocket-client~=1.8 in c:\projects\clinical\env\lib\site-packages (from selenium<5.0.0,>=4.18.1->crewai-tools) (1.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\projects\clinical\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\projects\clinical\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\projects\clinical\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\projects\clinical\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\projects\clinical\env\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.13.1)
# Requirement already satisfied: Mako in c:\projects\clinical\env\lib\site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.114->crewai) (1.3.5)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in c:\projects\clinical\env\lib\site-packages (from cachecontrol<0.15.0,>=0.14.0->cachecontrol[filecache]<0.15.0,>=0.14.0->poetry<2.0.0,>=1.8.3->crewai) (1.1.0)
# Requirement already satisfied: filelock>=3.8.0 in c:\projects\clinical\env\lib\site-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry<2.0.0,>=1.8.3->crewai) (3.16.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in c:\projects\clinical\env\lib\site-packages (from cleo<3.0.0,>=2.1.0->poetry<2.0.0,>=1.8.3->crewai) (3.10.0)
# Requirement already satisfied: boto3<2.0.0,>=1.34.0 in c:\projects\clinical\env\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.35.30)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\projects\clinical\env\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.9.7)
# Requirement already satisfied: httpx-sse==0.4.0 in c:\projects\clinical\env\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in c:\projects\clinical\env\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: sagemaker<3.0.0,>=2.232.1 in c:\projects\clinical\env\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (2.232.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\projects\clinical\env\lib\site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (2.32.0.20240914)
# Requirement already satisfied: cffi>=1.12 in c:\projects\clinical\env\lib\site-packages (from cryptography<44.0.0,>=43.0.1->auth0-python<5.0.0,>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\projects\clinical\env\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.22.0->crewai) (1.16.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\projects\clinical\env\lib\site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.22->crewai-tools) (0.38.6)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\projects\clinical\env\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.20.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\projects\clinical\env\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.35.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\projects\clinical\env\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.24.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\projects\clinical\env\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.18.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\projects\clinical\env\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (3.26.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\projects\clinical\env\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.12.5)
# Requirement already satisfied: shapely<3.0.0dev in c:\projects\clinical\env\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.0.6)
# Requirement already satisfied: httpcore==1.* in c:\projects\clinical\env\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\projects\clinical\env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\projects\clinical\env\lib\site-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.44.22->crewai) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\projects\clinical\env\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.44.22->crewai) (2.1.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\projects\clinical\env\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.44.22->crewai) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\projects\clinical\env\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.44.22->crewai) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\projects\clinical\env\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.44.22->crewai) (0.20.0)
# Requirement already satisfied: jaraco.classes in c:\projects\clinical\env\lib\site-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.8.3->crewai) (3.4.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\projects\clinical\env\lib\site-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.8.3->crewai) (0.2.3)
# Requirement already satisfied: six>=1.9.0 in c:\projects\clinical\env\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\projects\clinical\env\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools) (2.9.0.post0)
# Requirement already satisfied: requests-oauthlib in c:\projects\clinical\env\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\projects\clinical\env\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\projects\clinical\env\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools) (0.8)
# Requirement already satisfied: langchain-experimental>=0.0.6 in c:\projects\clinical\env\lib\site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (0.0.65)
# Requirement already satisfied: pandas>=1.4.3 in c:\projects\clinical\env\lib\site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (2.2.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in c:\projects\clinical\env\lib\site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\projects\clinical\env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\projects\clinical\env\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain<0.3.0,>=0.2.16->crewai) (1.33)
# Requirement already satisfied: neo4j<6.0.0,>=5.23.1 in c:\projects\clinical\env\lib\site-packages (from mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (5.25.0)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in c:\projects\clinical\env\lib\site-packages (from mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (2024.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in c:\projects\clinical\env\lib\site-packages (from mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (1.11.3)
# Requirement already satisfied: rank-bm25<0.3.0,>=0.2.2 in c:\projects\clinical\env\lib\site-packages (from mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (0.2.2)
# Requirement already satisfied: coloredlogs in c:\projects\clinical\env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\projects\clinical\env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools) (24.3.25)
# Requirement already satisfied: sympy in c:\projects\clinical\env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools) (1.13.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools) (75.1.0)
# Requirement already satisfied: asgiref~=3.0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools) (3.8.1)
# Requirement already satisfied: ptyprocess>=0.5 in c:\projects\clinical\env\lib\site-packages (from pexpect<5.0.0,>=4.7.0->poetry<2.0.0,>=1.8.3->crewai) (0.7.0)
# Requirement already satisfied: monotonic>=1.5 in c:\projects\clinical\env\lib\site-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.22->crewai-tools) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\projects\clinical\env\lib\site-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.22->crewai-tools) (2.2.1)
# Requirement already satisfied: decorator>=3.4.2 in c:\projects\clinical\env\lib\site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.4->crewai-tools) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\projects\clinical\env\lib\site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.4->crewai-tools) (1.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\projects\clinical\env\lib\site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\projects\clinical\env\lib\site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\projects\clinical\env\lib\site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain<0.2.0,>=0.1.114->crewai) (3.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\projects\clinical\env\lib\site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai-tools) (0.25.1)
# Requirement already satisfied: sortedcontainers in c:\projects\clinical\env\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai-tools) (2.4.0)
# Requirement already satisfied: outcome in c:\projects\clinical\env\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai-tools) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in c:\projects\clinical\env\lib\site-packages (from trio-websocket~=0.9->selenium<5.0.0,>=4.18.1->crewai-tools) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\projects\clinical\env\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium<5.0.0,>=4.18.1->crewai-tools) (1.7.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\projects\clinical\env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\projects\clinical\env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in c:\projects\clinical\env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools) (13.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\projects\clinical\env\lib\site-packages (from virtualenv<21.0.0,>=20.23.0->poetry<2.0.0,>=1.8.3->crewai) (0.3.8)
# Requirement already satisfied: botocore<1.36.0,>=1.35.30 in c:\projects\clinical\env\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.35.30)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\projects\clinical\env\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\projects\clinical\env\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.10.2)
# Requirement already satisfied: pycparser in c:\projects\clinical\env\lib\site-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python<5.0.0,>=4.7.1->crewai) (2.22)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\projects\clinical\env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\projects\clinical\env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\projects\clinical\env\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.62.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\projects\clinical\env\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\projects\clinical\env\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in c:\projects\clinical\env\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in c:\projects\clinical\env\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\projects\clinical\env\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\projects\clinical\env\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\projects\clinical\env\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai-tools) (2024.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\projects\clinical\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain<0.3.0,>=0.2.16->crewai) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\projects\clinical\env\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (0.1.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\projects\clinical\env\lib\site-packages (from pandas>=1.4.3->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (2024.2)
# Requirement already satisfied: grpcio-tools>=1.41.0 in c:\projects\clinical\env\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (1.62.3)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\projects\clinical\env\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (2.10.1)
# Requirement already satisfied: cloudpickle==2.2.1 in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (2.2.1)
# Requirement already satisfied: google-pasta in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.2.0)
# Requirement already satisfied: pathos in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.3.3)
# Requirement already satisfied: psutil in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (6.0.0)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.0 in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.0.9)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (3.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\projects\clinical\env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools) (10.0)
# Requirement already satisfied: more-itertools in c:\projects\clinical\env\lib\site-packages (from jaraco.classes->keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.8.3->crewai) (10.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\projects\clinical\env\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools) (1.3.0)
# Requirement already satisfied: h2<5,>=3 in c:\projects\clinical\env\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (4.1.0)
# Requirement already satisfied: pyreadline3 in c:\projects\clinical\env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\projects\clinical\env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.6.1)
# Requirement already satisfied: mock<5.0,>4.0 in c:\projects\clinical\env\lib\site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (4.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\projects\clinical\env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (1.0.0)
# Requirement already satisfied: ppft>=1.7.6.9 in c:\projects\clinical\env\lib\site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.9 in c:\projects\clinical\env\lib\site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.3.9)
# Requirement already satisfied: pox>=0.3.5 in c:\projects\clinical\env\lib\site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.3.5)
# Requirement already satisfied: multiprocess>=0.70.17 in c:\projects\clinical\env\lib\site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.70.17)
# Requirement already satisfied: hyperframe<7,>=6.0 in c:\projects\clinical\env\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in c:\projects\clinical\env\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (4.0.0)
# Requirement already satisfied: crewai in c:\projects\clinical\env\lib\site-packages (0.65.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python<5.0.0,>=4.7.1 in c:\projects\clinical\env\lib\site-packages (from crewai) (4.7.2)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in c:\projects\clinical\env\lib\site-packages (from crewai) (8.1.7)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.114 in c:\projects\clinical\env\lib\site-packages (from crewai) (0.1.122)
# Requirement already satisfied: instructor==1.3.3 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.3.3)
# Requirement already satisfied: json-repair<0.26.0,>=0.25.2 in c:\projects\clinical\env\lib\site-packages (from crewai) (0.25.3)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: langchain<0.3.0,>=0.2.16 in c:\projects\clinical\env\lib\site-packages (from crewai) (0.2.16)
# Requirement already satisfied: litellm<2.0.0,>=1.44.22 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.48.7)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.50.2)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.27.0)
# Requirement already satisfied: poetry<2.0.0,>=1.8.3 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.8.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in c:\projects\clinical\env\lib\site-packages (from crewai) (2.9.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\projects\clinical\env\lib\site-packages (from crewai) (1.0.1)
# Requirement already satisfied: regex<2025.0.0,>=2024.9.11 in c:\projects\clinical\env\lib\site-packages (from crewai) (2024.9.11)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (3.10.8)
# Requirement already satisfied: docstring-parser<0.17,>=0.16 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.5.0,>=0.4.1 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (0.4.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (2.23.4)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (13.8.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (8.5.0)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in c:\projects\clinical\env\lib\site-packages (from instructor==1.3.3->crewai) (0.12.5)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in c:\projects\clinical\env\lib\site-packages (from auth0-python<5.0.0,>=4.7.1->crewai) (43.0.1)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in c:\projects\clinical\env\lib\site-packages (from auth0-python<5.0.0,>=4.7.1->crewai) (2.9.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\projects\clinical\env\lib\site-packages (from auth0-python<5.0.0,>=4.7.1->crewai) (2.32.3)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in c:\projects\clinical\env\lib\site-packages (from auth0-python<5.0.0,>=4.7.1->crewai) (2.2.3)
# Requirement already satisfied: colorama in c:\projects\clinical\env\lib\site-packages (from click<9.0.0,>=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (1.13.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.24 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.4.24)
# Requirement already satisfied: cohere<6.0,>=5.3 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (5.11.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (1.68.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.44)
# Requirement already satisfied: langchain-cohere<0.2.0,>=0.1.4 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.9)
# Requirement already satisfied: langchain-community<0.3.0,>=0.2.6 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.2.17)
# Requirement already satisfied: langchain-openai<0.2.0,>=0.1.7 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.25)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.15 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.17)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (3.6.6)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (4.3.1)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.7.7)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (2.0.35)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in c:\projects\clinical\env\lib\site-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\projects\clinical\env\lib\site-packages (from langchain<0.3.0,>=0.2.16->crewai) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\projects\clinical\env\lib\site-packages (from langchain<0.3.0,>=0.2.16->crewai) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in c:\projects\clinical\env\lib\site-packages (from langchain<0.3.0,>=0.2.16->crewai) (0.2.41)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\projects\clinical\env\lib\site-packages (from langchain<0.3.0,>=0.2.16->crewai) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\projects\clinical\env\lib\site-packages (from langchain<0.3.0,>=0.2.16->crewai) (0.1.129)
# Requirement already satisfied: numpy<2,>=1 in c:\projects\clinical\env\lib\site-packages (from langchain<0.3.0,>=0.2.16->crewai) (1.26.4)
# ...
# Requirement already satisfied: jaraco.classes in c:\projects\clinical\env\lib\site-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.8.3->crewai) (3.4.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\projects\clinical\env\lib\site-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.8.3->crewai) (0.2.3)
# Requirement already satisfied: langchain-experimental>=0.0.6 in c:\projects\clinical\env\lib\site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (0.0.65)
# Requirement already satisfied: pandas>=1.4.3 in c:\projects\clinical\env\lib\site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (2.2.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in c:\projects\clinical\env\lib\site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\projects\clinical\env\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\projects\clinical\env\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain<0.3.0,>=0.2.16->crewai) (1.33)
# Requirement already satisfied: neo4j<6.0.0,>=5.23.1 in c:\projects\clinical\env\lib\site-packages (from mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (5.25.0)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in c:\projects\clinical\env\lib\site-packages (from mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (2024.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in c:\projects\clinical\env\lib\site-packages (from mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (1.11.3)
# Requirement already satisfied: rank-bm25<0.3.0,>=0.2.2 in c:\projects\clinical\env\lib\site-packages (from mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (0.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in c:\projects\clinical\env\lib\site-packages (from pexpect<5.0.0,>=4.7.0->poetry<2.0.0,>=1.8.3->crewai) (0.7.0)
# Requirement already satisfied: six>=1.5 in c:\projects\clinical\env\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\projects\clinical\env\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\projects\clinical\env\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in c:\projects\clinical\env\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\projects\clinical\env\lib\site-packages (from requests<3.0.0,>=2.31.0->auth0-python<5.0.0,>=4.7.1->crewai) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\projects\clinical\env\lib\site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\projects\clinical\env\lib\site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\projects\clinical\env\lib\site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain<0.2.0,>=0.1.114->crewai) (3.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\projects\clinical\env\lib\site-packages (from tokenizers->litellm<2.0.0,>=1.44.22->crewai) (0.25.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\projects\clinical\env\lib\site-packages (from virtualenv<21.0.0,>=20.23.0->poetry<2.0.0,>=1.8.3->crewai) (0.3.8)
# Requirement already satisfied: botocore<1.36.0,>=1.35.30 in c:\projects\clinical\env\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.35.30)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\projects\clinical\env\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\projects\clinical\env\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.10.2)
# Requirement already satisfied: pycparser in c:\projects\clinical\env\lib\site-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python<5.0.0,>=4.7.1->crewai) (2.22)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\projects\clinical\env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\projects\clinical\env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\projects\clinical\env\lib\site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.38.6)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\projects\clinical\env\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.62.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\projects\clinical\env\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\projects\clinical\env\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in c:\projects\clinical\env\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in c:\projects\clinical\env\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\projects\clinical\env\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\projects\clinical\env\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\projects\clinical\env\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.44.22->crewai) (2024.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\projects\clinical\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain<0.3.0,>=0.2.16->crewai) (3.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\projects\clinical\env\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\projects\clinical\env\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\projects\clinical\env\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\projects\clinical\env\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.8)
# Requirement already satisfied: mdurl~=0.1 in c:\projects\clinical\env\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (0.1.2)
# Requirement already satisfied: coloredlogs in c:\projects\clinical\env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\projects\clinical\env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (24.3.25)
# Requirement already satisfied: sympy in c:\projects\clinical\env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.13.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (75.1.0)
# Requirement already satisfied: asgiref~=3.0 in c:\projects\clinical\env\lib\site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.8.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\projects\clinical\env\lib\site-packages (from pandas>=1.4.3->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (2024.2)
# Requirement already satisfied: grpcio-tools>=1.41.0 in c:\projects\clinical\env\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (1.62.3)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\projects\clinical\env\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (2.10.1)
# Requirement already satisfied: cloudpickle==2.2.1 in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (2.2.1)
# Requirement already satisfied: docker in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (7.1.0)
# Requirement already satisfied: google-pasta in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.2.0)
# Requirement already satisfied: pathos in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.3.3)
# Requirement already satisfied: psutil in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (6.0.0)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.0 in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.0.9)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in c:\projects\clinical\env\lib\site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (3.0.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\projects\clinical\env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\projects\clinical\env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in c:\projects\clinical\env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (13.1)
# Requirement already satisfied: more-itertools in c:\projects\clinical\env\lib\site-packages (from jaraco.classes->keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.8.3->crewai) (10.5.0)
# Requirement already satisfied: h2<5,>=3 in c:\projects\clinical\env\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (4.1.0)
# Requirement already satisfied: pywin32>=226 in c:\projects\clinical\env\lib\site-packages (from portalocker<3.0.0,>=2.7.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (306)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\projects\clinical\env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.6.1)
# Requirement already satisfied: mock<5.0,>4.0 in c:\projects\clinical\env\lib\site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (4.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\projects\clinical\env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\projects\clinical\env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (10.0)
# Requirement already satisfied: ppft>=1.7.6.9 in c:\projects\clinical\env\lib\site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.9 in c:\projects\clinical\env\lib\site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.3.9)
# Requirement already satisfied: pox>=0.3.5 in c:\projects\clinical\env\lib\site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.3.5)
# Requirement already satisfied: multiprocess>=0.70.17 in c:\projects\clinical\env\lib\site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.70.17)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\projects\clinical\env\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.3.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in c:\projects\clinical\env\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in c:\projects\clinical\env\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.15->embedchain<0.2.0,>=0.1.114->crewai) (4.0.0)
# Requirement already satisfied: pyreadline3 in c:\projects\clinical\env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.5.4)

# %%
import sqlite3
import re
import json
import requests
from langchain.llms.base import LLM
from langchain.schema import Generation
from langchain.callbacks.manager import CallbackManagerForLLMRun
from typing import Any, Dict, Iterator, Optional, List

# LLM-related functionality
ngrok_url = "https://54bc-35-194-40-255.ngrok-free.app"

def query_llm(user_message):
    tokens = requests.post(f"{ngrok_url}get_num_tokens", headers={'Content-Type': 'application/json'}, data=json.dumps({"text": user_message}))
    tokens = tokens.json()
    print(tokens.get("num_tokens"))
    endpoint = f"{ngrok_url}/invoke_llm"
    question = f"""{user_message} assistant"""
    data = {"text": question}

    response = requests.post(endpoint, headers={'Content-Type': 'application/json'}, data=json.dumps(data))

    if response.status_code == 200:
        response_json = response.json()
        result_text = response_json.get('result', 'No result key in response')
        print(result_text)
        return result_text.strip()
    else:
        print(f"Request failed with status code: {response.status_code}")
        print(response.text)
        return response.text

# Custom LLM wrapper
class CustomLLM(LLM):
    custom_function: Any

    def __init__(self, custom_function: Any, **kwargs: Any):
        super().__init__(**kwargs)
        self.custom_function = custom_function

    def _call(self, prompt: str, stop: Optional[List[str]] = None, **kwargs: Any) -> str:
        if stop is not None:
            raise ValueError("stop kwargs are not permitted.")
        response = self.custom_function(prompt)
        return response

    def _stream(self, prompt: str, stop: Optional[List[str]] = None, **kwargs: Any) -> Iterator[Generation]:
        response = self.custom_function(prompt)
        for char in response:
            yield Generation(text=char)

    @property
    def _identifying_params(self) -> Dict[str, Any]:
        return {"model_name": "CustomChatModel"}

    @property
    def _llm_type(self) -> str:
        return "custom"

custom_llm = CustomLLM(custom_function=query_llm)

# %%
data_researcher_prompt_template = """
<|begin_of_text|><|start_header_id|>system<|end_header_id|>

You are a Data Researcher Agent. Your responsibility is to analyze the user's clinical trial-related question, extract relevant keywords using an LLM, and dynamically identify the appropriate tables and fields from the database schema. Then, provide structured information to be used for SQL query generation.

- **Tables**: Identify the relevant tables based on the extracted keywords.
- **Fields**: List the fields from these tables that are required to address the user query.
- **Conditions**: Identify any conditions or filters based on the user query.

Make sure the information is clear and structured for further SQL query generation.<|eot_id|>

<|start_header_id|>user<|end_header_id|>

{question}<|eot_id|>

<|start_header_id|>assistant<|end_header_id|>

Based on the user's query, the relevant database schema involves the following:
- **Tables**: {selected_tables}
- **Fields**: {selected_fields}
- **Conditions**: {conditions}

This information is ready for the next agent to process and generate the SQL query.<|eot_id|>
"""


sql_specialist_prompt_template = """
<|begin_of_text|><|start_header_id|>system<|end_header_id|>

You are an SQL Specialist Agent. Your responsibility is to take structured data (tables, fields, and conditions) from the Data Researcher Agent and use this information to generate an SQL query. The SQL query should be optimized for fetching clinical trial data from the database, while considering any necessary filters or conditions.

- **Tables**: Use the provided tables to generate the FROM clause.
- **Fields**: Include the listed fields in the SELECT clause.
- **Conditions**: Add the specified conditions in the WHERE clause if applicable.

Generate a well-formed SQL query using the provided information.<|eot_id|>

<|start_header_id|>data_researcher<|end_header_id|>

- Tables: {tables}
- Fields: {fields}
- Conditions: {conditions}<|eot_id|>

<|start_header_id|>assistant<|end_header_id|>

Here is the generated SQL query based on the provided information:
```sql
{sql_query}
"""


execution_agent_prompt_template = """
<|begin_of_text|><|start_header_id|>system<|end_header_id|>

You are an Execution Agent. Your task is to execute the nct ids driven from the clinical trials database. You take the user query and search for the appropriate nct_id related to it in the clinical trials database. Then, you will return the nct ids in a structured format.

Make sure to handle errors during execution and return an appropriate message.<|eot_id|>

<|start_header_id|>sql_specialist<|end_header_id|>

Here is the SQL query that needs to be executed:
```sql
{sql_query}
```<|eot_id|>

<|start_header_id|>assistant<|end_header_id|>

The query has been executed. Here are the results:
- **Results**: {query_results}

If there were errors, the output will indicate the issue.
This output is now ready for summarization.<|eot_id|>
"""


writer_agent_prompt_template = """
<|begin_of_text|><|start_header_id|>system<|end_header_id|>

You are a Writer Agent. Your role is to take raw results from the Execution Agent and summarize them in a human-readable format with the help of the llm. If the results are empty or no relevant data is found, generate an appropriate response indicating this.

Make sure the summary is concise, clear, and informative.

<|eot_id|>

<|start_header_id|>execution_agent<|end_header_id|>

Here are the query results that need to be summarized:
- **Results**: {query_results}<|eot_id|>

<|start_header_id|>assistant<|end_header_id|>

The summary of the retrieved data is:
{summary}

If there is no relevant data, output: "No relevant data found."<|eot_id|>
"""

# %%
import requests
import json
from typing import Any, Dict, List, Tuple
import sqlite3  

# Function to execute SQL query
def execute_sql_query(query: str) -> List[Dict[str, Any]]:
    print(f"Executing SQL query: {query}")
    # Replace with actual database interaction code
    try:
        conn = sqlite3.connect('clinical_trials.db')  
        cursor = conn.cursor()
        cursor.execute(query)
        results = cursor.fetchall()
        conn.close()
        return [dict(row) for row in results]  # Convert to list of dicts
    except Exception as e:
        print(f"Error executing query: {e}")
        return []

# %%
class DataResearcherAgent:
    """Fetches relevant information based on a user query."""
    def fetch_information(self, user_question):
        return f"DataResearcherAgent has fetched relevant research information for: {user_question}"

from typing import Dict, List, Any

class SQLSpecialistAgent:
    def __init__(self, schema_info: Dict[str, List[str]]):
        """
        Initialize the SQLSpecialistAgent with schema information.

        :param schema_info: A dictionary containing table names as keys and their respective field names as values.
        """
        self.schema_info = schema_info

    def generate_sql(self, extracted_info: Dict[str, Any]) -> str:
        """
        Generate SQL queries based on the extracted information, which includes
        tables, conditions, fields, and relationships.

        :param extracted_info: A dictionary containing the following keys:
            - "tables": List of table names to be queried.
            - "conditions": A dictionary of conditions for the WHERE clause.
            - "fields": List of field names to select. If empty, selects all fields.
        
        :return: A string containing the generated SQL query.
        """
        tables = extracted_info.get("tables", [])
        conditions = extracted_info.get("conditions", {})
        fields = extracted_info.get("fields", ["*"])  # Default to selecting all fields

        if not tables:
            return "SELECT * FROM studies LIMIT 10;"  # Default query if no specific table

        # Construct the SELECT clause with table prefixes
        if fields == ["*"]:
            select_clause = ', '.join(f"{table}.{field}" for table in tables for field in self.schema_info[table])
        else:
            select_clause = ', '.join(f"{table}.{field}" for field in fields for table in tables if field in self.schema_info[table])

        # Construct the FROM clause
        from_clause = ', '.join(tables)

        # Construct the WHERE clause based on conditions
        where_clauses = [f"{table}.{field} = '{value}'" for table, value in conditions.items() for table in tables if field in self.schema_info[table]]
        where_clause = ' AND '.join(where_clauses) if where_clauses else ""

        # Build the final SQL query
        sql_query = f"SELECT {select_clause} FROM {from_clause}"
        if where_clause:
            sql_query += f" WHERE {where_clause}"
        sql_query += " LIMIT 10;"  # Limiting results for safety

        return sql_query

# %%
class ExecutionAgent:
    def __init__(self, db_path='clinical_trials.db', llm=None):
        self.conn = self.connect_to_database(db_path)
        self.llm = llm

    def connect_to_database(self, db_path):
        try:
            conn = sqlite3.connect(db_path)
            print(f"Connected to database: {db_path}")
            return conn
        except sqlite3.Error as e:
            print(f"Error connecting to database: {e}")
            return None

    def fetch_nct_id(self, query_type, query_value):
        cursor = self.conn.cursor()
        if query_type == 'drug':
            cursor.execute(f"SELECT nct_id FROM all_interventions WHERE names LIKE ? LIMIT 50", (f'%{query_value}%',))
        elif query_type == 'condition':
            cursor.execute(f"SELECT nct_id FROM all_conditions WHERE names LIKE ? LIMIT 50", (f'%{query_value}%',))
        elif query_type == 'trial':
            cursor.execute(f"SELECT nct_id FROM all_keywords WHERE names LIKE ? LIMIT 50", (f'%{query_value}%',))

        results = cursor.fetchall()
        return [row[0] for row in results]

    def fetch_details_for_nct_id(self, nct_id):
        cursor = self.conn.cursor()
        cursor.execute(f"SELECT * FROM all_keywords WHERE nct_id = ?", (nct_id,))
        trial_details = cursor.fetchall()

        cursor.execute(f"SELECT * FROM all_interventions WHERE nct_id = ?", (nct_id,))
        drug_details = cursor.fetchall()

        cursor.execute(f"SELECT * FROM all_conditions WHERE nct_id = ?", (nct_id,))
        condition_details = cursor.fetchall()

        return trial_details, drug_details, condition_details

    def handle_user_query(self, user_question):
        query_type, query_value = self.map_question_to_query(user_question)
        if query_type and query_value:
            nct_ids = self.fetch_nct_id(query_type, query_value)
            if nct_ids:
                llm_input = f"Query results for {query_value} ({query_type}):\n"
                for nct_id in nct_ids:
                    trial_details, drug_details, condition_details = self.fetch_details_for_nct_id(nct_id)
                    llm_input += f"\nDetails for nct_id {nct_id}:\n"
                    llm_input += f"Trial Details: {trial_details}\n"
                    llm_input += f"Drug/Intervention Details: {drug_details}\n"
                    llm_input += f"Condition Details: {condition_details}\n"
                summary_request = f"Based on the following details:\n{llm_input}\nPlease summarize this information."
                if self.llm:
                    llm_output = self.llm._call(summary_request)
                    return llm_output
                else:
                    return None
            else:
                return None
        else:
            return None

    def map_question_to_query(self, question):
        question = question.lower()
        if "drug" in question or "intervention" in question or "treatment" in question:
            drug_match = re.search(r"(?:drug|intervention|treatment)\s*(?:for\s*)?(\w+)", question)
            if drug_match:
                return 'drug', drug_match.group(1)
        if "condition" in question or "disease" in question or "for" in question:
            condition_match = re.search(r"(?:condition|disease|for)\s*(\w+)", question)
            if condition_match:
                return 'condition', condition_match.group(1)
        if "trial" in question:
            trial_match = re.search(r"trial\s*(\w+)", question)
            if trial_match:
                return 'trial', trial_match.group(1)
        return None, None

    def close_connection(self):
        if self.conn:
            self.conn.close()

# %%
schema_info ={

 'all_id_information': ['nct_id', 'names'],
 'all_interventions': ['nct_id', 'names'],
 'all_intervention_types': ['nct_id', 'names'], 
'all_keywords': ['nct_id', 'names'], 
'all_overall_officials': ['nct_id', 'names'], 
'all_overall_official_affiliations': ['nct_id', 'names'],
 'all_primary_outcome_measures': ['nct_id', 'names'],
 'all_secondary_outcome_measures': ['nct_id', 'names'],
 'all_sponsors': ['nct_id', 'names'],
 'all_states': ['nct_id', 'names'],
 'analyzed_studies': ['id', 'nct_id', 'url', 'brief_title', 'start_month', 'start_year', 'overall_status', 'p_completion_month', 'p_completion_year', 'completion_month', 'completion_year', 'verification_month', 'verification_year', 'p_comp_mn', 'p_comp_yr', 'received_year', 'mntopcom', 'enrollment', 'number_of_arms', 'allocation', 'masking', 'phase', 'primary_purpose', 'sponsor_name', 'agency_class', 'collaborator_names', 'funding', 'responsible_party_type', 'responsible_party_organization', 'us_coderc', 'oversight', 'behavioral', 'biological', 'device', 'dietsup', 'drug', 'genetic', 'procedure', 'radiation', 'otherint', 'intervg1', 'results', 'resultsreceived_month', 'resultsreceived_year', 'firstreceived_results_dt', 't2result', 't2result_imp', 't2resmod', 'results12', 'delayed', 'dr_received_dt', 'mn2delay', 'delayed12'],
 'calculated_values': ['id', 'nct_id', 'number_of_facilities', 'number_of_nsae_subjects', 'number_of_sae_subjects', 'registered_in_calendar_year', 'nlm_download_date', 'actual_duration', 'were_results_reported', 'months_to_report_results', 'has_us_facility', 'has_single_facility', 'minimum_age_num', 'maximum_age_num', 'minimum_age_unit', 'maximum_age_unit', 'number_of_primary_outcomes_to_measure', 'number_of_secondary_outcomes_to_measure', 'number_of_other_outcomes_to_measure'],
 'designs': ['id', 'nct_id', 'allocation', 'intervention_model', 'observational_model', 'primary_purpose', 'time_perspective', 'masking', 'masking_description', 'intervention_model_description', 'subject_masked', 'caregiver_masked', 'investigator_masked', 'outcomes_assessor_masked'], 
'design_group_interventions': ['id', 'nct_id', 'design_group_id', 'intervention_id'],
 'participant_flows': ['id', 'nct_id', 'recruitment_details', 'pre_assignment_details', 'units_analyzed'],
 'responsible_parties': ['id', 'nct_id', 'responsible_party_type', 'name', 'title', 'organization', 'affiliation', 'old_name_title'], 
'result_agreements': ['id', 'nct_id', 'pi_employee', 'agreement', 'restriction_type', 'other_details', 'restrictive_agreement'], 
'result_contacts': ['id', 'nct_id', 'organization', 'name', 'phone', 'email', 'extension'],
 'result_groups': ['id', 'nct_id', 'ctgov_group_code', 'result_type', 'title', 'description', 'outcome_id'], 
'retractions': ['id', 'reference_id', 'pmid', 'source', 'nct_id'], 
'sponsors': ['id', 'nct_id', 'agency_class', 'lead_or_collaborator', 'name'],
 'all_conditions': ['nct_id', 'names'],
'studies': ['nct_id', 'nlm_download_date_description', 'study_first_submitted_date', 'results_first_submitted_date', 'disposition_first_submitted_date', 'last_update_submitted_date', 'study_first_submitted_qc_date', 'study_first_posted_date', 'study_first_posted_date_type', 'results_first_submitted_qc_date', 'results_first_posted_date', 'results_first_posted_date_type', 'disposition_first_submitted_qc_date', 'disposition_first_posted_date', 'disposition_first_posted_date_type', 'last_update_submitted_qc_date', 'last_update_posted_date', 'last_update_posted_date_type', 'start_month_year', 'start_date_type', 'start_date', 'verification_month_year', 'verification_date', 'completion_month_year', 'completion_date_type', 'completion_date', 'primary_completion_month_year', 'primary_completion_date_type', 'primary_completion_date', 'target_duration', 'study_type', 'acronym', 'baseline_population', 'brief_title', 'official_title', 'overall_status', 'last_known_status', 'phase', 'enrollment', 'enrollment_type', 'source', 'limitations_and_caveats', 'number_of_arms', 'number_of_groups', 'why_stopped', 'has_expanded_access', 'expanded_access_type_individual', 'expanded_access_type_intermediate', 'expanded_access_type_treatment', 'has_dmc', 'is_fda_regulated_drug', 'is_fda_regulated_device', 'is_unapproved_device', 'is_ppsd', 'is_us_export', 'biospec_retention', 'biospec_description', 'ipd_time_frame', 'ipd_access_criteria', 'ipd_url', 'plan_to_share_ipd', 'plan_to_share_ipd_description', 'created_at', 'updated_at', 'source_class', 'delayed_posting', 'expanded_access_nctid', 'expanded_access_status_for_nctid', 'fdaaa801_violation', 'baseline_type_units_analyzed', 'patient_registry'],
 'all_countries': ['nct_id', 'names'],
 'all_design_outcomes': ['nct_id', 'names'], 
'all_facilities': ['nct_id', 'names'],
 'all_group_types': ['nct_id', 'names']
}

# %%
# Integrating agents
class MultiAgentSystem:
    def __init__(self, llm, schema_info):
        self.data_researcher = DataResearcherAgent()
        self.sql_specialist = SQLSpecialistAgent(schema_info=schema_info)
        self.execution_agent = ExecutionAgent(llm=llm)

    def handle_query(self, user_question):
        # DataResearcherAgent output
        research_output = self.data_researcher.fetch_information(user_question)

        # SQL Specialist output
        extracted_info = {
            "tables": ["all_interventions", "all_conditions", "all_keywords"],  # Example tables to use
            "conditions": {},  # Placeholder for conditions, this can be expanded
            "fields": ["nct_id"],  # Placeholder for fields
        }
        sql_output = self.sql_specialist.generate_sql(extracted_info)

        # ExecutionAgent output
        execution_output = self.execution_agent.handle_user_query(user_question)

        # Combine and return the result from all agents
        combined_output = (
            f"Data Research Output: {research_output}\n"
            f"SQL Query Output: {sql_output}\n"
            f"Execution Output: {execution_output}"
        )
        return combined_output

    def close(self):
        self.execution_agent.close_connection()

# %%
# Dynamic question-answering process
def dynamic_question_process(multi_agent_system):
    print("Welcome to the Clinical Trials Query System!")
    print("You can ask questions related to drugs, conditions, or clinical trials.")
    while True:
        user_query = input("Enter your question (or type 'exit' to quit): ")
        if user_query.lower() == 'exit':
            break
        response = multi_agent_system.handle_query(user_query)
        print("Response:\n", response)

# Usage
if __name__ == "__main__":
    multi_agent_system = MultiAgentSystem(custom_llm, schema_info)
    dynamic_question_process(multi_agent_system)
    multi_agent_system.close()
# Out:
# Connected to database: clinical_trials.db
# Welcome to the Clinical Trials Query System!
# You can ask questions related to drugs, conditions, or clinical trials.
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\projects\clinical\env\lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File c:\projects\clinical\env\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File c:\projects\clinical\env\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File c:\projects\clinical\env\lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\projects\clinical\env\lib\site-packages\urllib3\connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\projects\clinical\env\lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\projects\clinical\env\lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\projects\clinical\env\lib\site-packages\urllib3\connection.py:693, in HTTPSConnection.connect(self)
#     692 sock: socket.socket | ssl.SSLSocket
# --> 693 self.sock = sock = self._new_conn()
#     694 server_hostname: str = self.host
#
# File c:\projects\clinical\env\lib\site-packages\urllib3\connection.py:206, in HTTPConnection._new_conn(self)
#     205 except socket.gaierror as e:
# --> 206     raise NameResolutionError(self.host, self, e) from e
#     207 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x0000021096ABB130>: Failed to resolve '54bc-35-194-40-255.ngrok-free.appget_num_tokens' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\projects\clinical\env\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\projects\clinical\env\lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File c:\projects\clinical\env\lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='54bc-35-194-40-255.ngrok-free.appget_num_tokens', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021096ABB130>: Failed to resolve '54bc-35-194-40-255.ngrok-free.appget_num_tokens' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[8], line 15
#      13 if __name__ == "__main__":
#      14     multi_agent_system = MultiAgentSystem(custom_llm, schema_info)
# ---> 15     dynamic_question_process(multi_agent_system)
#      16     multi_agent_system.close()
#
# Cell In[8], line 9, in dynamic_question_process(multi_agent_system)
#       7 if user_query.lower() == 'exit':
#       8     break
# ----> 9 response = multi_agent_system.handle_query(user_query)
#      10 print("Response:\n", response)
#
# Cell In[7], line 21, in MultiAgentSystem.handle_query(self, user_question)
#      18 sql_output = self.sql_specialist.generate_sql(extracted_info)
#      20 # ExecutionAgent output
# ---> 21 execution_output = self.execution_agent.handle_user_query(user_question)
#      23 # Combine and return the result from all agents
#      24 combined_output = (
#      25     f"Data Research Output: {research_output}\n"
#      26     f"SQL Query Output: {sql_output}\n"
#      27     f"Execution Output: {execution_output}"
#      28 )
#
# Cell In[5], line 54, in ExecutionAgent.handle_user_query(self, user_question)
#      52 summary_request = f"Based on the following details:\n{llm_input}\nPlease summarize this information."
#      53 if self.llm:
# ---> 54     llm_output = self.llm._call(summary_request)
#      55     return llm_output
#      56 else:
#
# Cell In[1], line 44, in CustomLLM._call(self, prompt, stop, **kwargs)
#      42 if stop is not None:
#      43     raise ValueError("stop kwargs are not permitted.")
# ---> 44 response = self.custom_function(prompt)
#      45 return response
#
# Cell In[1], line 14, in query_llm(user_message)
#      13 def query_llm(user_message):
# ---> 14     tokens = requests.post(f"{ngrok_url}get_num_tokens", headers={'Content-Type': 'application/json'}, data=json.dumps({"text": user_message}))
#      15     tokens = tokens.json()
#      16     print(tokens.get("num_tokens"))
#
# File c:\projects\clinical\env\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\projects\clinical\env\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\projects\clinical\env\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\projects\clinical\env\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\projects\clinical\env\lib\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='54bc-35-194-40-255.ngrok-free.appget_num_tokens', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021096ABB130>: Failed to resolve '54bc-35-194-40-255.ngrok-free.appget_num_tokens' ([Errno 11001] getaddrinfo failed)"))
